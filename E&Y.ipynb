# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel("C:/Users/H/Downloads/Telegram Desktop/Indian States Population and Area.xlsx")

# %%
df.head()
# Out:
#               State  Aadhaar assigned as of 2019  Area (per sq km)
# 0             Delhi                     21763471              1483
# 1           Haryana                     28941133             44212
# 2            Kerala                     36475649             38852
# 3  Himachal Pradesh                      7560770             55673
# 4            Punjab                     30355185             50362

# %%
df['Density'] = df['Aadhaar assigned as of 2019']//df['Area (per sq km)']

# %%
df.head()
# Out:
#               State  Aadhaar assigned as of 2019  Area (per sq km)  Density
# 0             Delhi                     21763471              1483    14675
# 1           Haryana                     28941133             44212      654
# 2            Kerala                     36475649             38852      938
# 3  Himachal Pradesh                      7560770             55673      135
# 4            Punjab                     30355185             50362      602

# %%
df.sort_values(by = 'Density')
# Out:
#                         State  Aadhaar assigned as of 2019  Area (per sq km)  \
# 33                     Ladakh                       210156             59146
# 31          Arunachal Pradesh                      1229964             83743
# 35                  Meghalaya                       978281             22429
# 32            Jammu & Kashmir                     10436172            222236
# 14  Andaman & Nicobar Islands                       387019              8249
# 25                    Mizoram                      1089577             21081
# 34                   Nagaland                      1262729             16579
# 28                     Sikkim                       578914              7096
# 36                      Assam                      6755448             78438
# 30                    Manipur                      2515724             22327
# 3            Himachal Pradesh                      7560770             55673
# ...

# %%
af = pd.read_csv("C:/Users/H/Downloads/Telegram Desktop/lockdownindiawarningzones.csv")

# %%
af['State'].value_counts()
# Out:
# Uttar Pradesh                  75
# Madhya Pradesh                 52
# Bihar                          38
# Tamil Nadu                     37
# Maharashtra                    36
# Assam                          33
# Rajasthan                      33
# Gujarat                        33
# Telangana                      33
# Odisha                         30
# Karnataka                      30
# Chhattisgarh                   27
# Arunachal Pradesh              25
# Jharkhand                      24
# West Bengal                    23
# Haryana                        22
# Punjab                         22
# Jammu And Kashmir              20
# Manipur                        16
# Kerala                         14
# Uttarakhand                    13
# Andhra Pradesh                 13
# Himachal Pradesh               12
# Mizoram                        11
# Delhi                          11
# Nagaland                       11
# Meghalaya                      11
# ...

# %%
af.loc[(af.State=='Dadra And Nagar Haveli') & (af.Zone=='Green Zone')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 140 to 140
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   S.no      1 non-null      int64
#  1   District  1 non-null      object
#  2   State     1 non-null      object
#  3   Zone      1 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 40.0+ bytes

# %%
for i in range(len(df)):
    if df['State'][i]=='Dadra & Nagar Haveli':
        df['RedZone'][i] = 0
        df['GreenZone'][i] = 100
        df['OrangeZone'][i] = 0
# Out:
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\H\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.to_excel("C:/Users/H/Downloads/Telegram Desktop/Indian States Population and Area.xlsx")

# %%
df = pd.read_excel("C:/Users/H/Downloads/Telegram Desktop/E&Y FINAL.xlsx")

# %%
df = df.drop(columns = ["Unnamed: 0"])

# %%
df.head()
# Out:
#               State  Aadhaar assigned as of 2019  Area (per sq km)  Density  \
# 0             Delhi                     21763471              1483    14675
# 1           Haryana                     28941133             44212      654
# 2            Kerala                     36475649             38852      938
# 3  Himachal Pradesh                      7560770             55673      135
# 4            Punjab                     30355185             50362      602
#
#    RedZone  GreenZone  OrangeZone
# 0      100          0           0
# 1        9          9          81
# 2       14         14          71
# 3        0         50          50
# 4       18         18          63

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
mat = df.corr()

# %%
sns.heatmap(mat,annot = True)
plt.show()

# %%
x = df['State']
y = df['RedZone']
plt.scatter(x,y)
x = df['State']
y = df['GreenZone']
plt.scatter(x,y)
x = df['State']
y = df['OrangeZone']
plt.scatter(x,y)
plt.show()
